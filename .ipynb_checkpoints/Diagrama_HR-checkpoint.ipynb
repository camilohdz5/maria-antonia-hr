# %%
# !pip install astroquery
# Out:
# Requirement already satisfied: astroquery in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (0.4.10)
# Requirement already satisfied: numpy>=1.20 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (2.3.2)
# Requirement already satisfied: astropy>=5.0 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (7.1.0)
# Requirement already satisfied: requests>=2.19 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (2.32.3)
# Requirement already satisfied: beautifulsoup4>=4.8 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (4.13.4)
# Requirement already satisfied: html5lib>=0.999 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (1.1)
# Requirement already satisfied: keyring>=15.0 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (25.6.0)
# Requirement already satisfied: pyvo>=1.5 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astroquery) (1.7)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astropy>=5.0->astroquery) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astropy>=5.0->astroquery) (0.2025.8.18.0.40.14)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astropy>=5.0->astroquery) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from astropy>=5.0->astroquery) (24.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from beautifulsoup4>=4.8->astroquery) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from beautifulsoup4>=4.8->astroquery) (4.13.2)
# Requirement already satisfied: six>=1.9 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from html5lib>=0.999->astroquery) (1.17.0)
# Requirement already satisfied: webencodings in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from html5lib>=0.999->astroquery) (0.5.1)
# Requirement already satisfied: jaraco.classes in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from keyring>=15.0->astroquery) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from keyring>=15.0->astroquery) (4.3.0)
# Requirement already satisfied: jaraco.context in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from keyring>=15.0->astroquery) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.19->astroquery) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.19->astroquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.19->astroquery) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.19->astroquery) (2025.4.26)
# Requirement already satisfied: more-itertools in /Users/camilohdz5/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from jaraco.classes->keyring>=15.0->astroquery) (10.7.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from astroquery.gaia import Gaia
import astropy.units as u

# %%
query = """
SELECT bp_rp, phot_g_mean_mag, parallax
FROM gaiadr3.gaia_source
WHERE parallax > 3
  AND parallax_over_error > 10
  AND bp_rp IS NOT NULL
  AND phot_g_mean_mag IS NOT NULL
"""
job = Gaia.launch_job_async(query)
data = job.get_results()
# Out:
# INFO:astroquery:Query finished.
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
# Filtrar datos
bp_rp = data['bp_rp']
phot_g = data['phot_g_mean_mag']
parallax = data['parallax']  # en milisegundos de arco (mas)

# Magnitud absoluta: M_G = G + 5 * log10(parallax/1000) + 5
M_G = phot_g + 5 * np.log10(parallax / 1000) + 5

# Diagrama HR
plt.figure(figsize=(10, 10))
plt.scatter(bp_rp, M_G, s=1, c=bp_rp, cmap='viridis', alpha=0.6)
plt.colorbar(label='Color (BP-RP)')

plt.gca().invert_yaxis()
plt.xlabel('Color (BP-RP)')
plt.ylabel('Magnitud Absoluta G')
plt.title('Diagrama HR de Maria ANtonia (Gaia, <200 pc)')
plt.grid(alpha=0.3)
plt.xlim(-0.5, 3)
plt.ylim(20, -5)
plt.show()

# %%
# Nueva celda - Diagrama con anotaciones
plt.figure(figsize=(12, 10))
plt.scatter(bp_rp, M_G, s=1, color='b', alpha=0.5)

# Anotar regiones importantes
plt.annotate('Secuencia Principal', xy=(0.5, 5), fontsize=12, 
             bbox=dict(boxstyle="round,pad=0.3", facecolor="yellow", alpha=0.7))
plt.annotate('Gigantes Rojas', xy=(1.5, -2), fontsize=12,
             bbox=dict(boxstyle="round,pad=0.3", facecolor="red", alpha=0.7))

plt.gca().invert_yaxis()
plt.xlabel('Color (BP-RP)')
plt.ylabel('Magnitud Absoluta G')
plt.title('Diagrama HR con Regiones Identificadas')
plt.grid(alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Nueva celda - Diagrama con anotaciones
# ----> 2 plt.figure(figsize=(12, 10))
#       3 plt.scatter(bp_rp, M_G, s=1, color='b', alpha=0.5)
#       5 # Anotar regiones importantes
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(10, 10))
plt.scatter(bp_rp, M_G, s=1, c=bp_rp, cmap='viridis', alpha=0.6)
plt.colorbar(label='Color (BP-RP)')

plt.gca().invert_yaxis()
plt.xlabel('Color (BP-RP)')
plt.ylabel('Magnitud Absoluta G')
plt.title('Diagrama HR real (Gaia, <200 pc)')
plt.grid(alpha=0.3)
plt.xlim(-0.5, 3)
plt.ylim(20, -5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize=(10, 10))
#       2 plt.scatter(bp_rp, M_G, s=1, c=bp_rp, cmap='viridis', alpha=0.6)
#       3 plt.colorbar(label='Color (BP-RP)')
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from astroquery.gaia import Gaia
import astropy.units as u

# %%
plt.figure(figsize=(10, 10))
plt.scatter(bp_rp, M_G, s=1, c=bp_rp, cmap='viridis', alpha=0.6)
plt.colorbar(label='Color (BP-RP)')

plt.gca().invert_yaxis()
plt.xlabel('Color (BP-RP)')
plt.ylabel('Magnitud Absoluta G')
plt.title('Diagrama HR real (Gaia, <200 pc)')
plt.grid(alpha=0.3)
plt.xlim(-0.5, 3)
plt.ylim(20, -5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.figure(figsize=(10, 10))
#       2 plt.scatter(bp_rp, M_G, s=1, c=bp_rp, cmap='viridis', alpha=0.6)
#       3 plt.colorbar(label='Color (BP-RP)')
#
# NameError: name 'plt' is not defined
